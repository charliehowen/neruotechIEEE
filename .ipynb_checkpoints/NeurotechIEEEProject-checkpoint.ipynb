# %% [markdown]
# Main Question:
# Does brain training work?
#
# Sub Questions:
# Is there a statistically significant difference between the pre and post test scores? -- BOTH
#
# Do performance changes on the two training intervention tasks differ? How do they each relate to changes in pre- and post-intervention performance? -- CHARLIE
#
# How well can we predict post-intervention performance? Beyond pre-intervention performance, what factors serve as the best predictors? -- JOE
#
# Tests Used: ahhhhh

# %%
# %matplotlib inline
import pandas as pd
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import plotly.plotly as py
import plotly.tools as tls

os.path.isfile('/home/harper/Documents/neurotechIEEE/PrePostData/TestingDataALL1.csv')

df = pd.read_csv('/home/harper/Documents/neurotechIEEE/PrePostData/TestingDataALL1.csv')

df.head()
# Out:
#    Subject  Age  Gender  PreFigureSeries  PreLSATReasoning  \
# 0       10   21       1               24                13
# 1       11   20       2               20                15
# 2       12   20       1               15                11
# 3       13   21       2               18                10
# 4       14   21       1               20                14
#
#    PreLetterComp_Accuracy  PreLetterComp_AttemptedTrials  \
# 0                0.869565                           23.0
# 1                0.962963                           27.0
# 2                1.000000                           21.0
# 3                0.958333                           24.0
# 4                1.000000                           24.0
#
#    PreLetterComp_CorrectTrials  PreLetterComp_AvgRT  \
# 0                         20.0          2465.565217
# 1                         26.0          2074.962963
# 2                         21.0          2679.047619
# 3                         23.0          2348.083333
# 4                         24.0          2239.333333
#
#    PreLetterComp_AvgCorrectTrialRT  PreDSST_Attempted  PreDSST_Correct  \
# 0                      2281.150000                 82               82
# 1                      2062.730769                113              113
# 2                      2679.047619                 76               76
# 3                      2417.652174                124              124
# 4                      2239.333333                106              106
#
#    PreDSST_Accuracy  PostFigureSeries  PostLSATReasoning  \
# 0               1.0                25                  6
# 1               1.0                26                 13
# 2               1.0                 7                 10
# 3               1.0                19                 11
# 4               1.0                15                 13
#
#    PrePatternComp_Accuracy  PrePatternComp_AttemptedTrials  \
# 0                 0.976744                              43
# 1                 1.000000                              30
# 2                 0.900000                              30
# 3                 0.936170                              47
# 4                 0.933333                              45
#
#    PrePatternComp_CorrectTrials  PrePatternComp_AvgRT  \
# 0                            42           1248.720930
# 1                            30           1718.400000
# 2                            27           1839.200000
# 3                            44           1117.765957
# 4                            42           1197.733333
#
#    PrePatternComp_AvgCorrectTrialRT
# 0                       1239.857143
# 1                       1718.400000
# 2                       1858.629630
# 3                       1131.750000
# 4                       1200.238095

# %%
df.set_index('Subject')
df.sort_values(['Subject']).head()
# Out:
#     Subject  Age  Gender  PreFigureSeries  PreLSATReasoning  \
# 10        1   34       1               15                 9
# 17        2   30       1               21                13
# 18        3   22       2               23                19
# 19        4   19       1               23                14
# 20        5   20       1               15                16
#
#     PreLetterComp_Accuracy  PreLetterComp_AttemptedTrials  \
# 10                1.000000                           26.0
# 17                1.000000                           24.0
# 18                     NaN                            NaN
# 19                0.888889                           27.0
# 20                0.862069                           29.0
#
#     PreLetterComp_CorrectTrials  PreLetterComp_AvgRT  \
# 10                         26.0          2176.846154
# 17                         24.0          2232.958333
# 18                          NaN                  NaN
# 19                         24.0          2099.518519
# 20                         25.0          1944.965517
#
#     PreLetterComp_AvgCorrectTrialRT  PreDSST_Attempted  PreDSST_Correct  \
# 10                      2176.846154                 87               87
# 17                      2232.958333                 86               85
# 18                              NaN                 90               89
# 19                      2091.458333                 91               91
# 20                      1894.080000                 99               98
#
#     PreDSST_Accuracy  PostFigureSeries  PostLSATReasoning  \
# 10          1.000000                17                 13
# 17          0.988372                28                 14
# 18          0.988889                30                 19
# 19          1.000000                23                 10
# 20          0.989899                19                 11
#
#     PrePatternComp_Accuracy  PrePatternComp_AttemptedTrials  \
# 10                 0.970588                              34
# 17                 1.000000                              32
# 18                 0.962264                              53
# 19                 0.942857                              35
# 20                 0.935484                              31
#
#     PrePatternComp_CorrectTrials  PrePatternComp_AvgRT  \
# 10                            33           1583.970588
# 17                            32           1723.062500
# 18                            51           1000.452830
# 19                            33           1539.685714
# 20                            29           1785.548387
#
#     PrePatternComp_AvgCorrectTrialRT
# 10                       1566.333333
# 17                       1723.062500
# 18                       1011.411765
# 19                       1522.969697
# 20                       1755.103448

# %% [raw]
# df['PostFigureSeries'].describe()

# %%
df['PreFigureSeries'].describe()
# Out:
# count    25.00000
# mean     19.04000
# std       5.15978
# min      10.00000
# 25%      15.00000
# 50%      19.00000
# 75%      23.00000
# max      29.00000
# Name: PreFigureSeries, dtype: float64

# %%
plt.boxplot(df['PreFigureSeries'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fe9313ea650>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe93194ed90>,
#   <matplotlib.lines.Line2D at 0x7fe93191ea50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe93193f0d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe93191e610>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fe9313ea890>,
#   <matplotlib.lines.Line2D at 0x7fe93194e990>]}
